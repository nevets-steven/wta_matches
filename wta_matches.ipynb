# %% [markdown]
# # Question 1

# %%
import pandas as pd

# %%
wta_csv = pd.read_csv('wta_matches_2022/wta_matches_2022.csv')

# %%
wta_csv.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date
# 0  2022-2014   Adelaide 1    Hard         30             P      20220103  \
# 1  2022-2014   Adelaide 1    Hard         30             P      20220103
# 2  2022-2014   Adelaide 1    Hard         30             P      20220103
# 3  2022-2014   Adelaide 1    Hard         30             P      20220103
# 4  2022-2014   Adelaide 1    Hard         30             P      20220103
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon
# 0        300     202458           1          NaN  ...    19.0     16.0  \
# 1        299     202458           1          NaN  ...    39.0     27.0
# 2        298     214981           7          NaN  ...    45.0     29.0
# 3        297     202458           1          NaN  ...    54.0     34.0
# 4        296     216347           5          NaN  ...    45.0     30.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points
# ...

# %% [markdown]
# # Question 2

# %%
wta_tsv = pd.read_csv('wta_matches_2022/wta_matches_2022.tsv', delimiter='\t')

# %%
wta_tsv.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date
# 0  2022-2014   Adelaide 1    Hard         30             P      20220103  \
# 1  2022-2014   Adelaide 1    Hard         30             P      20220103
# 2  2022-2014   Adelaide 1    Hard         30             P      20220103
# 3  2022-2014   Adelaide 1    Hard         30             P      20220103
# 4  2022-2014   Adelaide 1    Hard         30             P      20220103
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon
# 0        300     202458           1          NaN  ...    19.0     16.0  \
# 1        299     202458           1          NaN  ...    39.0     27.0
# 2        298     214981           7          NaN  ...    45.0     29.0
# 3        297     202458           1          NaN  ...    54.0     34.0
# 4        296     216347           5          NaN  ...    45.0     30.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points
# ...

# %% [markdown]
# # Question 3

# %%
wta_xlsx = pd.read_excel('wta_matches_2022/wta_matches_2022.xlsx', sheet_name='wta_matches')

# %%
wta_xlsx.tail()
# Out:
#                            tourney_id                tourney_name surface
# 2589  2022-W-FC-2022-QLS-M-ROU-POL-01  BJK Cup QLS R1: ROU vs POL    Hard  \
# 2590  2022-W-FC-2022-QLS-M-USA-UKR-01  BJK Cup QLS R1: USA vs UKR    Hard
# 2591  2022-W-FC-2022-QLS-M-USA-UKR-01  BJK Cup QLS R1: USA vs UKR    Hard
# 2592  2022-W-FC-2022-QLS-M-USA-UKR-01  BJK Cup QLS R1: USA vs UKR    Hard
# 2593  2022-W-FC-2022-QLS-M-USA-UKR-01  BJK Cup QLS R1: USA vs UKR    Hard
#
#       draw_size tourney_level  tourney_date  match_num  winner_id winner_seed
# 2589          4             D      20220415          3     216347         NaN  \
# 2590          4             D      20220415          1     201590         NaN
# 2591          4             D      20220415          2     202468         NaN
# 2592          4             D      20220415          3     215035         NaN
# 2593          4             D      20220415          4     215290         NaN
#
# ...

# %% [markdown]
# # Question 4

# %%
wta_parquet = pd.read_parquet('wta_matches_2022/wta_matches_2022.parquet')
wta_parquet.describe()
# Out:
#          draw_size  tourney_date    match_num      winner_id    winner_ht
# count  2594.000000  2.594000e+03  2594.000000    2594.000000  2284.000000  \
# mean     58.169622  2.022057e+07   231.574402  208749.718196   174.442207
# std      40.908905  2.837332e+02    87.224054    6905.465396     5.769077
# min       2.000000  2.022010e+07     1.000000  200033.000000   157.000000
# 25%      32.000000  2.022032e+07   199.000000  202434.000000   170.000000
# 50%      32.000000  2.022061e+07   275.000000  206290.500000   175.000000
# 75%      96.000000  2.022082e+07   288.000000  214643.000000   179.000000
# max     128.000000  2.022111e+07   300.000000  260672.000000   185.000000
#
#         winner_age       loser_id     loser_ht    loser_age  best_of  ...
# count  2592.000000    2594.000000  2040.000000  2590.000000   2594.0  ...  \
# mean     26.284375  209466.639938   173.944118    26.171776      3.0  ...
# std       4.186044    7397.775922     6.056689     4.313521      0.0  ...
# ...

# %% [markdown]
# ### This dataset is showing me that there is a wide range of ages, draw sizes and types of matches within the dataset. I can see that most of the winners in the bracket are mainly within the top 25 seedings in the world, which adds up since you gain seeds based on wins.
#
# ### Younger aged players tend to win more because of their atheltism and experience.

# %% [markdown]
# # Question 5

# %%
print('CSV File: ')
# %time wta_csv = pd.read_csv('wta_matches_2022/wta_matches_2022.csv')
print('')
print('XLSX "Excel" File: ')
# %time wta_xlsx = pd.read_excel('wta_matches_2022/wta_matches_2022.xlsx', sheet_name='wta_matches')
print('')
print('TSV File: ')
# %time wta_tsv = pd.read_csv('wta_matches_2022/wta_matches_2022.tsv', delimiter='\t')
print('')
print('Parquet File: ')
# %time wta_parquet = pd.read_parquet('wta_matches_2022/wta_matches_2022.parquet')
# Out:
# CSV File:
# CPU times: user 24.3 ms, sys: 6.95 ms, total: 31.3 ms
# Wall time: 63.2 ms
#
# XLSX "Excel" File:
# CPU times: user 3.37 s, sys: 71.3 ms, total: 3.44 s
# Wall time: 4.22 s
#
# TSV File:
# CPU times: user 26 ms, sys: 5.05 ms, total: 31 ms
# Wall time: 37.7 ms
#
# Parquet File:
# CPU times: user 17.1 ms, sys: 2.45 ms, total: 19.6 ms
# Wall time: 13.7 ms

# %% [markdown]
# ### parquet is the fastest file

# %% [markdown]
# ## What are these files about?
#
# ### These files are describing all the 2022 World Tennis Association matches showing their specific tournamet IDs, names, along with descriptives such as surface type, draw (pool) size, the skill level and dates for the tournament.
#
# ### On top of the tournament descriptions it also goes into the player info as well. It shows thw winner and loser specifics from seeding, entry, dominant hand, height, age, and name.
#
# ### In the later columsn you can see the scores of the games, along with each winner or loser of that game statistics of certain game events such as Aces, Defaults, Serve Points, Games Served, Rank Points, Series Length (best of) and duration in minutes.

# %%
wta_xlsx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2594 entries, 0 to 2593
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2594 non-null   object
#  1   tourney_name        2594 non-null   object
#  2   surface             2594 non-null   object
#  3   draw_size           2594 non-null   int64
#  4   tourney_level       2594 non-null   object
#  5   tourney_date        2594 non-null   int64
#  6   match_num           2594 non-null   int64
#  7   winner_id           2594 non-null   int64
#  8   winner_seed         1053 non-null   object
#  9   winner_entry        335 non-null    object
#  10  winner_name         2594 non-null   object
#  11  winner_hand         2594 non-null   object
#  12  winner_ht           2284 non-null   float64
#  13  winner_ioc          2594 non-null   object
#  14  winner_age          2592 non-null   float64
# ...
